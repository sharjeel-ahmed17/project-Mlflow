# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('C:\\Users\\CJ\\project-Mlflow\\src\\data\\raw\\ship_fuel_raw.csv')
df.head()
# Out:
#   ship_id         ship_type             route_id     month  distance  \
# 0   NG001  Oil Service Boat          Warri-Bonny   January    132.26
# 1   NG001  Oil Service Boat  Port Harcourt-Lagos  February    128.52
# 2   NG001  Oil Service Boat  Port Harcourt-Lagos     March     67.30
# 3   NG001  Oil Service Boat  Port Harcourt-Lagos     April     71.68
# 4   NG001  Oil Service Boat          Lagos-Apapa       May    134.32
#
#   fuel_type  fuel_consumption  CO2_emissions weather_conditions  \
# 0       HFO           3779.77       10625.76             Stormy
# 1       HFO           4461.44       12779.73           Moderate
# 2       HFO           1867.73        5353.01               Calm
# 3    Diesel           2393.51        6506.52             Stormy
# 4       HFO           4267.19       11617.03               Calm
#
#    engine_efficiency
# 0              92.14
# 1              92.98
# 2              87.61
# 3              87.42
# 4              85.61

# %%
# Data Exploration
print(df.describe())
# Out:
#           distance  fuel_consumption  CO2_emissions  engine_efficiency
# count  1440.000000       1440.000000    1440.000000        1440.000000
# mean    151.753354       4844.246535   13365.454882          82.582924
# std     108.472230       4892.352813   13567.650118           7.158289
# min      20.080000        237.880000     615.680000          70.010000
# 25%      79.002500       1837.962500    4991.485000          76.255000
# 50%     123.465000       3060.880000    8423.255000          82.775000
# 75%     180.780000       4870.675000   13447.120000          88.862500
# max     498.550000      24648.520000   71871.210000          94.980000

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1440 entries, 0 to 1439
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ship_id             1440 non-null   object
#  1   ship_type           1440 non-null   object
#  2   route_id            1440 non-null   object
#  3   month               1440 non-null   object
#  4   distance            1440 non-null   float64
#  5   fuel_type           1440 non-null   object
#  6   fuel_consumption    1440 non-null   float64
#  7   CO2_emissions       1440 non-null   float64
#  8   weather_conditions  1440 non-null   object
#  9   engine_efficiency   1440 non-null   float64
# dtypes: float64(4), object(6)
# memory usage: 112.6+ KB
# None

# %%
print(df.columns)
# Out:
# Index(['ship_id', 'ship_type', 'route_id', 'month', 'distance', 'fuel_type',
#        'fuel_consumption', 'CO2_emissions', 'weather_conditions',
#        'engine_efficiency'],
#       dtype='object')

# %%
print(df.isnull().sum())
# Out:
# ship_id               0
# ship_type             0
# route_id              0
# month                 0
# distance              0
# fuel_type             0
# fuel_consumption      0
# CO2_emissions         0
# weather_conditions    0
# engine_efficiency     0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
# Drop columns that are not needed 
df = df.drop(columns=['ship_id', 'route_id','CO2_emissions'])
df.columns
# Out:
# Index(['ship_type', 'month', 'distance', 'fuel_type', 'fuel_consumption',
#        'weather_conditions', 'engine_efficiency'],
#       dtype='object')

# %%
df.ship_type.value_counts()
# Out:
# ship_type
# Oil Service Boat    408
# Tanker Ship         408
# Surfer Boat         324
# Fishing Trawler     300
# Name: count, dtype: int64

# %%
df.month.value_counts()
# Out:
# month
# January      120
# February     120
# March        120
# April        120
# May          120
# June         120
# July         120
# August       120
# September    120
# October      120
# November     120
# December     120
# Name: count, dtype: int64

# %%
df.fuel_type.value_counts()
# Out:
# fuel_type
# Diesel    899
# HFO       541
# Name: count, dtype: int64

# %%
df.weather_conditions.value_counts()
# Out:
# weather_conditions
# Calm        516
# Stormy      462
# Moderate    462
# Name: count, dtype: int64

# %%
# seperate features and target variable
x=df.drop(columns=['fuel_consumption'])
y=df['fuel_consumption']

# %%
print(x)
# Out:
#              ship_type      month  distance fuel_type weather_conditions  \
# 0     Oil Service Boat    January    132.26       HFO             Stormy
# 1     Oil Service Boat   February    128.52       HFO           Moderate
# 2     Oil Service Boat      March     67.30       HFO               Calm
# 3     Oil Service Boat      April     71.68    Diesel             Stormy
# 4     Oil Service Boat        May    134.32       HFO               Calm
# ...                ...        ...       ...       ...                ...
# 1435   Fishing Trawler     August     63.84    Diesel             Stormy
# 1436   Fishing Trawler  September     61.43       HFO               Calm
# 1437   Fishing Trawler    October    193.09       HFO             Stormy
# 1438   Fishing Trawler   November    166.50    Diesel           Moderate
# 1439   Fishing Trawler   December    127.66    Diesel           Moderate
#
#       engine_efficiency
# 0                 92.14
# 1                 92.98
# 2                 87.61
# 3                 87.42
# 4                 85.61
# ...                 ...
# 1435              75.88
# 1436              78.00
# 1437              79.67
# 1438              92.87
# 1439              90.82
#
# [1440 rows x 6 columns]

# %%
print(y)
# Out:
# 0       3779.77
# 1       4461.44
# 2       1867.73
# 3       2393.51
# 4       4267.19
#          ...
# 1435    1633.85
# 1436    1263.48
# 1437    4661.63
# 1438    4298.00
# 1439    3549.91
# Name: fuel_consumption, Length: 1440, dtype: float64

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\cj\appdata\local\programs\python\python313\lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\cj\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (2.3.3)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\cj\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\cj\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\cj\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer

# %%
# feature transformation pipeline
categorical_cols = ["ship_type", "month", "fuel_type", "weather_conditions"]
numeric_cols = ["distance", "engine_efficiency"]

preprocessor = ColumnTransformer([
    ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_cols),
    ("num", StandardScaler(), numeric_cols)
])

# %%
# fit and transform the features
x = preprocessor.fit_transform(x)

# %%
print(x)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 8640 stored elements and shape (1440, 23)>
#   Coords	Values
#   (0, 1)	1.0
#   (0, 8)	1.0
#   (0, 17)	1.0
#   (0, 20)	1.0
#   (0, 21)	-0.179770677745266
#   (0, 22)	1.3355699960780423
#   (1, 1)	1.0
#   (1, 7)	1.0
#   (1, 17)	1.0
#   (1, 19)	1.0
#   (1, 21)	-0.2142615267299413
#   (1, 22)	1.452957233665665
#   (2, 1)	1.0
#   (2, 11)	1.0
#   (2, 17)	1.0
#   (2, 18)	1.0
#   (2, 21)	-0.7788416804309662
#   (2, 22)	0.7025173933733645
#   (3, 1)	1.0
#   (3, 4)	1.0
#   (3, 16)	1.0
#   (3, 20)	1.0
#   (3, 21)	-0.7384486540799291
#   (3, 22)	0.6759655182047359
#   (4, 1)	1.0
#   :	:
#   (1435, 22)	-0.9367115315109334
#   (1436, 0)	1.0
#   (1436, 15)	1.0
#   (1436, 17)	1.0
#   (1436, 18)	1.0
#   (1436, 21)	-0.8329757134630638
#   (1436, 22)	-0.6404485033136004
#   (1437, 0)	1.0
#   (1437, 14)	1.0
#   (1437, 17)	1.0
#   (1437, 20)	1.0
#   (1437, 21)	0.3812128366231323
#   (1437, 22)	-0.4070714952524938
#   (1438, 0)	1.0
#   (1438, 13)	1.0
#   (1438, 16)	1.0
#   (1438, 19)	1.0
#   (1438, 21)	0.13599581135507857
#   (1438, 22)	1.4375850954101432
#   (1439, 0)	1.0
#   (1439, 6)	1.0
#   (1439, 16)	1.0
#   (1439, 19)	1.0
#   (1439, 21)	-0.2221925775659898
#   (1439, 22)	1.1511043370117775
